# %% [markdown]
# What is NLP

# %% [markdown]
# -text classification
# -spam filters
# -voice text messaging
# -sentiment analysis
# -spell or grammar check
# -chat bot
# -search suggestion
# -search autocorrect
# -automatic review analysis system
# -machile translation
# -and so much more

# %% [markdown]
# skleran,spacy,NLTK

# %%
pip install spacy
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/8f/82/7e082fae7d642fc1794741805ac728911257b96144d080f7314e5f2632f2/spacy-2.3.1-cp37-cp37m-win_amd64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/46/62/7663894f67ac5a41a0d8812d78d9d2a9404124051885af9d77dc526fb399/tqdm-4.47.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/8b/6f/7cd666630afeb9b85cbd23c75da76b61580e45a9fe1c19145e3f7675ffc8/thinc-7.4.1-cp37-cp37m-win_amd64.whl
# ...
#   Found existing installation: tqdm 4.36.1
#     Uninstalling tqdm-4.36.1:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\tqdm-4.36.1.dist-info\\entry_points.txt'
# Consider using the `--user` option or check the permissions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spam.csv',encoding = "ISO-8859-1")

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
# v1            5572 non-null object
# v2            5572 non-null object
# Unnamed: 2    50 non-null object
# Unnamed: 3    12 non-null object
# Unnamed: 4    6 non-null object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df = df[['v1','v2']]
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df['length']  = df['v2'].str.len()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#         v1                                                 v2  length
# 0      ham  Go until jurong point, crazy.. Available only ...     111
# 1      ham                      Ok lar... Joking wif u oni...      29
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3      ham  U dun say so early hor... U c already then say...      49
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61
# ...    ...                                                ...     ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...     161
# 5568   ham              Will Ì_ b going to esplanade fr home?      37
# 5569   ham  Pity, * was in mood for that. So...any other s...      57
# 5570   ham  The guy did some bitching but I acted like i'd...     125
# 5571   ham                         Rofl. Its true to its name      26
#
# [5572 rows x 3 columns]

# %%
import string
>>> import operator
>>> import functools

# %%
count = lambda l1,l2: sum([1 for x in l1 if x in l2])

df['count_punct'] = df.v2.apply(lambda s: count(s, string.punctuation))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#         v1                                                 v2  length  \
# 0      ham  Go until jurong point, crazy.. Available only ...     111
# 1      ham                      Ok lar... Joking wif u oni...      29
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3      ham  U dun say so early hor... U c already then say...      49
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61
# ...    ...                                                ...     ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...     161
# 5568   ham              Will Ì_ b going to esplanade fr home?      37
# 5569   ham  Pity, * was in mood for that. So...any other s...      57
# 5570   ham  The guy did some bitching but I acted like i'd...     125
# 5571   ham                         Rofl. Its true to its name      26
#
#       count_punct
# 0               9
# 1               6
# 2               6
# 3               6
# 4               2
# ...

# %%
df.isnull().sum()
# Out:
# v1             0
# v2             0
# length         0
# count_punct    0
# dtype: int64

# %%
len(df)
# Out:
# 5572

# %%
df.rename({'v1': 'label', 'v2': 'message'}, axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
df
# Out:
#      label                                            message  length  \
# 0      ham  Go until jurong point, crazy.. Available only ...     111
# 1      ham                      Ok lar... Joking wif u oni...      29
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3      ham  U dun say so early hor... U c already then say...      49
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61
# ...    ...                                                ...     ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...     161
# 5568   ham              Will Ì_ b going to esplanade fr home?      37
# 5569   ham  Pity, * was in mood for that. So...any other s...      57
# 5570   ham  The guy did some bitching but I acted like i'd...     125
# 5571   ham                         Rofl. Its true to its name      26
#
#       count_punct
# 0               9
# 1               6
# 2               6
# 3               6
# 4               2
# ...

# %%
df.label.value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
#Imbalanced data

# %%
# balancein deh

# %%
ham = df[df['label']=='ham']
ham.head()
# Out:
#   label                                            message  length  \
# 0   ham  Go until jurong point, crazy.. Available only ...     111
# 1   ham                      Ok lar... Joking wif u oni...      29
# 3   ham  U dun say so early hor... U c already then say...      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61
# 6   ham  Even my brother is not like to speak with me. ...      77
#
#    count_punct
# 0            9
# 1            6
# 3            6
# 4            2
# 6            2

# %%
spam = df[df['label']=='spam']
spam.head()
# Out:
#    label                                            message  length  \
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...     148
# 8   spam  WINNER!! As a valued network customer you have...     158
# 9   spam  Had your mobile 11 months or more? U R entitle...     154
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...     136
#
#     count_punct
# 2             6
# 5             8
# 8             6
# 9             2
# 11            8

# %%
ham.shape,spam.shape
# Out:
# ((4825, 4), (747, 4))

# %%
ham =ham.sample(spam.shape[0])

# %%
ham.shape
# Out:
# (747, 4)

# %%
ham.shape,spam.shape
# Out:
# ((747, 4), (747, 4))

# %%
# udh balance gabungin deh

# %%
data = ham.append(spam,ignore_index=True)
data.tail()
# Out:
#      label                                            message  length  \
# 1489  spam  Want explicit SEX in 30 secs? Ring 02073162414...      90
# 1490  spam  ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...     160
# 1491  spam  Had your contract mobile 11 Mnths? Latest Moto...     160
# 1492  spam  REMINDER FROM O2: To get 2.50 pounds free call...     147
# 1493  spam  This is the 2nd time we have tried 2 contact u...     161
#
#       count_punct
# 1489            3
# 1490            5
# 1491            8
# 1492            3
# 1493            8

# %% [markdown]
# # EDA

# %%
plt.hist(data[data['label']=='ham']['length'],bins=100,alpha=0.7)
plt.hist(data[data['label']=='spam']['length'],bins=100,alpha=0.7)
plt.show()

# %%
plt.hist(data[data['label']=='ham']['count_punct'],bins=100,alpha=0.7)
plt.hist(data[data['label']=='spam']['count_punct'],bins=100,alpha=0.7)
plt.show()

# %%
# data preparation

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.pipeline import Pipeline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
X_train,X_test,y_train,y_test = train_test_split(data['message'],data['label'],test_size = 0.3,random_state=0,shuffle=True,stratify = data['label'])

# %%
#proporsinya bener bener sessuai

# %%
y_train
# Out:
# 1128    spam
# 742      ham
# 477      ham
# 542      ham
# 1277    spam
#         ...
# 1211    spam
# 312      ham
# 268      ham
# 272      ham
# 1222    spam
# Name: label, Length: 1045, dtype: object

# %%
X_train
# Out:
# 1128    UÛªve Bin Awarded å£50 to Play 4 Instant Cash...
# 742                          Gud mrng dear hav a nice day
# 477     Huh so early.. Then Ì_ having dinner outside i...
# 542                                Get the door, I'm here
# 1277    Ringtone Club: Gr8 new polys direct to your mo...
#                               ...
# 1211    Bloomberg -Message center +447797706009 Why wa...
# 312     A famous quote : when you develop the ability ...
# 268     Honey ? Sweetheart ? Darling ? Sexy buns ? Sug...
# 272                              I wanna watch that movie
# 1222    Text BANNEDUK to 89555 to see! cost 150p texto...
# Name: message, Length: 1045, dtype: object

# %%
y_train[y_train=='spam']
# Out:
# 1128    spam
# 1277    spam
# 789     spam
# 1319    spam
# 1005    spam
#         ...
# 1091    spam
# 1171    spam
# 1069    spam
# 1211    spam
# 1222    spam
# Name: label, Length: 523, dtype: object

# %%
y_train[y_train=='ham']
# Out:
# 742    ham
# 477    ham
# 542    ham
# 736    ham
# 140    ham
#       ...
# 22     ham
# 364    ham
# 312    ham
# 268    ham
# 272    ham
# Name: label, Length: 522, dtype: object

# %%
#bag of words

# %%
# vectorizer = TfidfVectorizer()

# %%
# X_train = vectorizer.fit_transform(X_train)

# %%
X_train.shape
# Out:
# (1045, 3691)

# %%
# artinya ada 1045 messages,dan ada 3634 unique words

# %%
X_train
# Out:
# <1045x3691 sparse matrix of type '<class 'numpy.float64'>'
# 	with 17672 stored elements in Compressed Sparse Row format>

# %%
1045 * 3634
# Out:
# 3797530

# %% [markdown]
# ### pipeline and SVM

# %%
clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',SVC(C=300,gamma='auto'))])

# %%
clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('clf', SVC(C=300, gamma='auto'))])

# %%
y_pred = clf.predict(X_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[222,   3],
#        [ 21, 203]], dtype=int64)

# %%
#cari tau menampilkan yang salah aja

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.91      0.99      0.95       225
#         spam       0.99      0.91      0.94       224
#
#     accuracy                           0.95       449
#    macro avg       0.95      0.95      0.95       449
# weighted avg       0.95      0.95      0.95       449

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9465478841870824

# %%
clf.predict(["Hi,this is Laxmi Kant"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(["Hi,i am imanta"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(["Congratulations,you have won free ticket to USA this summer.TEXT 'WON' to 445566 "])
# Out:
# array(['spam'], dtype=object)

# %%
clf.predict(["Congratulations,you have won free ticket to USA this summer"])
# Out:
# array(['spam'], dtype=object)

# %%
clf.predict(["you have won free ticket to USA this summer"])
# Out:
# array(['spam'], dtype=object)

# %%
clf.predict(["you have got free ticket to USA this summer"])
# Out:
# array(['spam'], dtype=object)

# %%
clf.predict(["you have got ticket to USA this summer"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(["your observation is ready"])
# Out:
# array(['spam'], dtype=object)

# %% [markdown]
# ### pipeline and RF

# %%
clf = Pipeline([('tfidf',TfidfVectorizer()),('clf', RandomForestClassifier(n_estimators=100,n_jobs=-1))])

# %%
clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('clf', RandomForestClassifier(n_jobs=-1))])

# %%
y_pred = clf.predict(X_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[224,   1],
#        [ 29, 195]], dtype=int64)

# %%
#cari tau menampilkan yang salah aja

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.89      1.00      0.94       225
#         spam       0.99      0.87      0.93       224
#
#     accuracy                           0.93       449
#    macro avg       0.94      0.93      0.93       449
# weighted avg       0.94      0.93      0.93       449

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.933184855233853

# %%
clf.predict(["Hi,this is Laxmi Kant"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(["Hi,i am imanta"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(["Congratulations,you have won free ticket to USA this summer.TEXT 'WON' to 445566 "])
# Out:
# array(['spam'], dtype=object)

# %%
clf.predict(["Congratulations,you have won free ticket to USA this summer"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(["you have won free ticket to USA this summer"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(["your observation is ready"])
# Out:
# array(['ham'], dtype=object)
